# %%
x = np.random.uniform(0, 2, 10000)
y = x**3

# %%
subplot(311)
pylab.hist(x, 100, histtype='step', normed=True)
subplot(312)
pylab.hist(y, 100, histtype='step', normed=True);

def f(y):
    return 1.0/(6.0*y**(2.0/3.0))

subplot(313)
xs = np.linspace(0.1, 8, 100)
plot(xs, f(xs), c='red');

# %%
def g(x):
    return np.clip(4-x**2, 0, None)
    
a = 5
b = 2
xs = np.linspace(-4,10,100)
plot(xs, g(xs))
plot(xs, 1.0/b * g((xs-a)/b), c='red');
