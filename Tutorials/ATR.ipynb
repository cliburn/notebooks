# %%
reject = [11.9, 6.3, 15.9, 13.0]
cmv = [43.6, 42.9, 32.7, 4.3]
bk = [22.8, 17.5, 25.2, 26.1]

# %%
scatter(reject, cmv, s=50)

# %%
scatter(reject, bk, s=50)
xlabel('Reject (percent)', fontsize=16)
ylabel('BK (percent)', fontsize=16)
title('Correlation of BK infection and Rejection', fontsize=16)
